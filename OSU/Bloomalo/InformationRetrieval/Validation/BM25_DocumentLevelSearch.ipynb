# %%
! pip install rank_bm25
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.22.4)

# %%
from rank_bm25 import BM25Okapi

# %%
import pandas as pd

df=pd.read_csv('CompleteMainText.csv')
df_just_text=df[['DocID','Text','URL']]
# print(df_just_text)
df_just_text['Text'] = df_just_text['Text'].str.replace("\n"," ")
corpus = df_just_text['Text'].tolist()
print(len(corpus))
# corpus['Text']=corpus['Text'].tolist()
# Out:
# 198
# <ipython-input-5-a151e8a71717>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_just_text['Text'] = df_just_text['Text'].str.replace("\n"," ")

# %%
# df_corpus_token['Text'] = [string.replace("\n"," ") for string in df_just_text['Text']]
# print(df_corpus_token['Text'][0])

# %%
tokenized_corpus = [doc.split(" ") for doc in corpus]

# %%
df_tokenized_corpus=df_just_text.copy()
df_tokenized_corpus['Text'] = [doc.split(" ") for doc in df_just_text['Text']]
tokenized_corpus = df_tokenized_corpus['Text'].tolist()
# df_tokenized_corpus['Text'][0]
# df_tokenized_corpus['Text'][0]

# %%
bm25 = BM25Okapi(tokenized_corpus)

# %%
# df_corpus=df_just_text.copy()
# df_corpus_token=df_just_text.copy()
# df_corpus_token['Text'] = [doc.replace("\n"," ").split(" ") for doc in df_corpus['Text']]

# %%
# print(df_corpus_token)

# %%
# bm25 = BM25Okapi(df_corpus_token['Text'])

# %%
query_list = ["fidgety child unable to sit still",
"child is forgetful in daily activities",
"child disregards rules",
"child not falling asleep in own bed",
"bedwetting in school age children",
"my child worries a lot",
"my child argues with me and screams",
"defiant argumentative behavior in child",
"potty training tips for toddlers",
"handling toddler tantrums",
"child is distracted and cannot focus",
"destructive and aggressive behavior in child"]

tokenized_query=[]
for query in query_list:
  tokenized_query.append(query.split(" "))

# %%
# tokenized_query

# %%
# bm25.get_top_n(tokenized_query[0], corpus, n=5)

# %%
# doc_scores = bm25.get_scores(tokenized_query)

# %%
# top_text=bm25.get_top_n(tokenized_query, corpus, n=2)

# %%
# doc_index=df_corpus_token[df_corpus_token['Text'] == s, 'DocID'].iloc[0]

# %%
final_document_List=[]
diction={}

for a,single_query in enumerate(tokenized_query):
  top_text=bm25.get_top_n(single_query, corpus, n=5)
  # print(top_text)
  # print(df_corpus_token['Text']==top_text[0])
  # mask = df_corpus_token['Title'].apply(lambda x: set(top_text[0]).issubset(set(x)) if isinstance(x, list) else False)
  # doc_Index = df_corpus_token[mask]['DocID']
  # print(doc_Index)

  if query_list[a] not in diction:
        diction[query_list[a]] = []
  
  doc_scores = bm25.get_scores(single_query)
  final_score=sorted(doc_scores)
  for i,s in enumerate(top_text):
    # print(s)
    # print(df_corpus[df_corpus_token['Text'] == s, 'DocID'].iloc[0])
    index=corpus.index(s)
    # print("IndexValuue is->"+ str(index))
    # print("DFID is ->"+str(df_just_text.iloc[index]['DocID']))
    # index = df_just_text.loc[df_just_text['Text']==s].index.tolist()[0]
    # index = df_just_text.loc[df_just_text['Text']==s]['DocID'].item()

    # print(index)
    doc_index=df_just_text.iloc[index]['DocID']
    url=df_just_text.iloc[index]['URL']
    # if doc_index>20:
    #   doc_index+=2
    # elif doc_index<20 and doc_index>8:
    #   doc_index+=1

    # doc_index=df_corpus_token[df_corpus_token['Text'] == s, 'DocID'].iloc[0]
    # doc_index=df.loc[df['Title'] == title, 'DocID'].iloc[0]
    title=df.iloc[index]['Title']
    # print("Document ID-> "+str(index))
    # print("Title ->"+str(title))
    score=final_score[-(i+1)]
    diction[query_list[a]].append((doc_index,title,score,url))
    # print("Rank"+str(i)+"DocID-> :"+str(index)

print(diction)
# Out:
# {'fidgety child unable to sit still': [(116, "How to Understand Your Child's Temperament - HealthyChildren.org", 9.828414820361512, 'https://healthychildren.org/English/ages-stages/gradeschool/Pages/How-to-Understand-Your-Childs-Temperament.aspx'), (180, "Some Kids Really Are More Difficult—Here's Why It Happens and How to Deal", 9.50575433208952, 'https://www.parents.com/toddlers-preschoolers/discipline/some-kids-really-are-more-difficult-heres-why-it-happens-and-how-to-deal/'), (25, 'Common Time-Out Mistakes and How to Solve Them', 8.977202449465551, 'https://www.parents.com/toddlers-preschoolers/discipline/time-out/common-time-out-mistakes-and-how-to-solve-them/'), (49, 'Toilet Training  (for Parents) - Nemours KidsHealth', 8.58987526267408, 'https://kidshealth.org/en/parents/toilet-teaching.html#catbehavior'), (112, 'Developmental Milestones: 4 to 5 Year Olds - HealthyChildren.org', 8.417528536518333, 'https://healthychildren.org/English/ages-stages/preschool/Pages/Developmental-Milestones-4-to-5-Year-Olds.aspx')], 'child is forgetful in daily activities': [(148, '7 Ways to Encourage Speech from a Speech Language Pathologist - Motherly', 11.023382677522156, 'https://www.mother.ly/toddler/toddler-milestones/when-do-babies-start-talking/'), (95, 'Dealing With the Terrible 2s: Tantrums', 10.666876972547392, 'https://www.webmd.com/parenting/guide/the-dreaded-terrible-2s'), (116, "How to Understand Your Child's Temperament - HealthyChildren.org", 10.400631913337904, 'https://healthychildren.org/English/ages-stages/gradeschool/Pages/How-to-Understand-Your-Childs-Temperament.aspx'), (68, "How to Build Your Child's Confidence and Self-Esteem - Child Development Institute", 10.35925569754368, 'https://childdevelopmentinfo.com/parenting/how-to-build-your-childs-confidence-and-self-esteem/'), (112, 'Developmental Milestones: 4 to 5 Year Olds - HealthyChildren.org', 10.292838790307636, 'https://healthychildren.org/English/ages-stages/preschool/Pages/Developmental-Milestones-4-to-5-Year-Olds.aspx')], 'child disregards rules': [(6, "What to Do If a Child Won't Respond to Rules or Consequences | Psychology Today", 6.293518036020856, 'https://www.psychologytoday.com/us/blog/all-grown/201808/what-do-if-child-wont-respond-rules-or-consequences'), (113, 'Growing Independence: Tips for Parents of Young Children - HealthyChildren.org', 5.804022492620572, 'https://healthychildren.org/English/ages-stages/preschool/Pages/Growing-Independence-Tips-for-Parents-of-Young-Children.aspx'), (17, 'Oppositional Defiant Disorder in Children: What To Know', 5.156215511864167, 'https://www.parents.com/kids/development/behavioral/i-thought-my-child-was-just-misbehaving-but-it-was-really-odd/'), (100, 'Create a Potty Training Plan for Your Child - HealthyChildren.org', 4.979631274752169, 'https://healthychildren.org/English/ages-stages/toddler/toilet-training/Pages/creating-a-toilet-training-plan.aspx'), (1, 'Parenting a Child with ADHD | Psychology Today', 4.935986144742973, 'https://www.psychologytoday.com/us/basics/adhd/parenting-adhd-child')], 'child not falling asleep in own bed': [(189, "Solutions for Kids' Sleep Problems", 16.758120366407777, 'https://www.parents.com/toddlers-preschoolers/sleep/issues/solutions-for-kids-sleep-problems/'), (188, 'How to Sleep Train Toddlers and Big Kids', 16.57741339262837, 'https://www.parents.com/toddlers-preschoolers/sleep/issues/how-to-sleep-train-toddlers-and-big-kids/'), (191, 'The Age-by-Age Guide to Better Bedtimes', 15.017438766419433, 'https://www.parents.com/toddlers-preschoolers/sleep/schedule/how-to-have-happier-bedtimes-and-better-sleep/'), (160, 'Early Bedtimes Make Everyone Happier - Motherly', 14.029065048208732, 'https://www.mother.ly/child/child-sleep/its-science-early-bedtimes-and-the-routines-behind-them-make-everyone-happier/'), (157, 'How to Beat Toddler Bedtime Struggles - Motherly', 13.460290697062264, 'https://www.mother.ly/child/child-sleep/toddler-bedtime-struggles/')], 'bedwetting in school a ...

# %%
# query='bed wetting'
# for t in diction[query]:
#   print('Score-> '+str(t[2]))
#   print('Title-> '+t[1])
#   print('URL-> '+t[3])

# %%
final_df = pd.DataFrame(columns=['Query','rank','Title','DocID','score','URL'])
length=1
for qn,query in enumerate(diction):
  rank=1
  for t in diction[query]:
    docID=t[0]
    title=t[1]
    score=t[2]
    url=t[3]
    final_df.loc[len(final_df)] = [query, rank, title, docID, score,url]
    # final_df.append((query,rank,title,docID,score))
    rank+=1
    length+=1

final_df
# Out:
#                                            Query  rank  \
# 0              fidgety child unable to sit still     1
# 1              fidgety child unable to sit still     2
# 2              fidgety child unable to sit still     3
# 3              fidgety child unable to sit still     4
# 4              fidgety child unable to sit still     5
# 5         child is forgetful in daily activities     1
# 6         child is forgetful in daily activities     2
# 7         child is forgetful in daily activities     3
# 8         child is forgetful in daily activities     4
# 9         child is forgetful in daily activities     5
# 10                        child disregards rules     1
# 11                        child disregards rules     2
# 12                        child disregards rules     3
# 13                        child disregards rules     4
# 14                        child disregards rules     5
# 15           child not falling asleep in own bed     1
# 16           child not falling asleep in own bed     2
# 17           child not falling asleep in own bed     3
# 18           child not falling asleep in own bed     4
# 19           child not falling asleep in own bed     5
# 20             bedwetting in school age children     1
# 21             bedwetting in school age children     2
# 22             bedwetting in school age children     3
# 23             bedwetting in school age children     4
# 24             bedwetting in school age children     5
# 25                        my child worries a lot     1
# 26                        my child worries a lot     2
# 27                        my child worries a lot     3
# 28                        my child worries a lot     4
# 29                        my child worries a lot     5
# 30           my child argues with me and screams     1
# 31           my child argues with me and screams     2
# 32           my child argues with me and screams     3
# 33           my child argues with me and screams     4
# 34           my child argues with me and screams     5
# 35       defiant argumentative behavior in child     1
# 36       defiant argumentative behavior in child     2
# 37       defiant argumentative behavior in child     3
# 38       defiant argumentative behavior in child     4
# 39       defiant argumentative behavior in child     5
# 40              potty training tips for toddlers     1
# 41              potty training tips for toddlers     2
# 42              potty training tips for toddlers     3
# 43              potty training tips for toddlers     4
# 44              potty training tips for toddlers     5
# 45                     handling toddler tantrums     1
# 46                     handling toddler tantrums     2
# 47                     handling toddler tantrums     3
# 48                     handling toddler tantrums     4
# 49                     handling toddler tantrums     5
# 50          child is distracted and cannot focus     1
# 51          child is distracted and cannot focus     2
# 42  https://www.parenting.com/toddler/potty-traini...
# 43  https://www.webmd.com/parenting/baby/potty-tra...
# 44  https://healthychildren.org/English/ages-stage...
# 45  https://www.parents.com/toddlers-preschoolers/...
# 46  https://www.parents.com/toddlers-preschoolers/...
# 47  https://kidshealth.org/en/parents/tantrums.htm...
# 48  https://www.mother.ly/toddler/toddler-mileston...
# 49  https://www.mother.ly/toddler/toddler-mileston...
# 50  https://www.parents.com/toddlers-preschoolers/...
# 51  https://healthychildren.org/English/ages-stage...
# 52  https://www.psychologytoday.com/us/blog/how-ra...
# 53  https://www.healthychildren.org/English/ages-s...
# 54  https://www.healthychildren.org/English/ages-s...
# 55  https://www.parents.com/toddlers-preschoolers/...
# 56  https://www.healthychildren.org/English/ages-s...
# 57  https://www.psychologytoday.com/us/basics/adhd...
# 58  https://childrensmd.org/browse-by-topic/parent...
# 59  https://www.psychologytoday.com/us/blog/up-and...

# %% [markdown]
# Structuring result dictionary to fit into Evaluation Library

# %%
# df = pd.DataFrame(final_df)
temp_result={}
result_dict={}
filtered_df=pd.DataFrame(columns=['Query','DocID','score'])
for i,query in enumerate(query_list):
  filtered_df=final_df.loc[final_df['Query'] == query, ['DocID', 'score']]
  # print(final_df.loc[final_df['Query'] == query, ['DocID', 'score']])
  # Assuming the dataframe is named "df"
  docIDs=filtered_df['DocID'].tolist()
  scores=filtered_df['score'].tolist()
  qID="q_"+str(i+1)
  for j,value in enumerate(docIDs):
    dID="d_"+str(value)
    if qID not in result_dict:
      result_dict[qID]={}
      result_dict[qID][dID]=scores[j]
    else:
      result_dict[qID][dID]=scores[j]
  # selected_rows = final_df[final_df['Query'] == query][['DocID', 'score']]
  # Assuming the dataframe is named "selected_rows"
  # selected_rows['DocID'] = selected_rows['DocID'].apply(lambda x: 'd_' + str(x))
  # result_dict = {temp: selected_rows.to_dict('records')}
  # print(filtered_df)

print(filtered_df)
  # temp_result[temp]=
# Out:
#     DocID      score
# 55    174  10.763920
# 56     70  10.555352
# 57      1  10.148365
# 58     59  10.069589
# 59    145  10.068893

# %%
print(result_dict['q_2'])
# Out:
# {'d_148': 11.023382677522156, 'd_95': 10.666876972547392, 'd_116': 10.400631913337904, 'd_68': 10.35925569754368, 'd_112': 10.292838790307636}

# %%
# for_dic = {}
# for i,query in enumerate(query_list):
#   temp="d_"+str(i)
#   for_dic[temp]=

# %% [markdown]
# Validation Start

# %%
! pip install ranx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ranx
#   Downloading ranx-0.3.8-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.10/dist-packages (from ranx) (0.56.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from ranx) (4.65.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ranx) (1.5.3)
# Collecting lz4
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ranx) (1.10.1)
# Collecting ir-datasets
#   Downloading ir_datasets-0.5.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 31.9 MB/s eta 0:00:00
# Collecting cbor2
#   Downloading cbor2-5.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.6/224.6 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ranx) (1.22.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ranx) (13.3.4)
# Collecting orjson
#   Downloading orjson-3.8.11-cp310-cp310-manylinux_2_28_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from ranx) (0.8.10)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54.1->ranx) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.54.1->ranx) (67.7.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->ranx) (6.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->ranx) (2.27.1)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting zlib-state>=0.1.3
#   Downloading zlib-state-0.1.5.tar.gz (9.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.2.0.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.3/113.3 kB 9.0 MB/s eta 0:00:00
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->ranx) (4.11.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->ranx) (4.9.2)
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.9.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ranx) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ranx) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ranx) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ranx) (2.14.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->ranx) (2.4.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->ranx) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->ranx) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (2.0.12)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyautocorpus, warc3-wet-clueweb09, zlib-state, cbor
#   Building wheel for pyautocorpus (setup.py) ... done
#   Created wheel for pyautocorpus: filename=pyautocorpus-0.1.9-cp310-cp310-linux_x86_64.whl size=189824 sha256=38d7f15599271ea3db2f75c3274b3b8c736ec51579479c1f0bf35191d945866a
#   Stored in directory: /root/.cache/pip/wheels/e2/be/43/ec1e16468c393f6e474e3be6ec6f17fad2216c088328348630
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18918 sha256=3e39baaa4725d13eef49bd358b05d2d65c7371ed86c0281f29ec37fcffb13327
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/91/7ffb991df87e62355d945745035470ba2616aa3d83a250b5f9
#   Building wheel for zlib-state (setup.py) ... done
#   Created wheel for zlib-state: filename=zlib_state-0.1.5-cp310-cp310-linux_x86_64.whl size=26634 sha256=ce303dc1c8cf74e1dbc20ce3e2a36ad9958f7f558ecdb28f38e8bc54ac6cb366
#   Stored in directory: /root/.cache/pip/wheels/f8/7a/4e/8fa633b918bea99c052211d41caf8529707d7eae1099d5e5dd
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp310-cp310-linux_x86_64.whl size=57665 sha256=4ef70fc2429c615b65e9112120f1dd8758da1bd95c9ef1c19cbf1df580f86b13
#   Stored in directory: /root/.cache/pip/wheels/85/df/c9/b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
# Successfully built pyautocorpus warc3-wet-clueweb09 zlib-state cbor
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, ijson, cbor, zlib-state, unlzw3, trec-car-tools, pyautocorpus, orjson, lz4, cbor2, ir-datasets, ranx
# Successfully installed cbor-1.0.0 cbor2-5.4.6 ijson-3.2.0.post0 ir-datasets-0.5.4 lz4-4.3.2 orjson-3.8.11 pyautocorpus-0.1.9 ranx-0.3.8 trec-car-tools-2.6 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 zlib-state-0.1.5

# %%
from ranx import Qrels, Run

qrels_dict = { "q_1": { "d_65":2, "d_69":2, "d_173":2, "d_1":2, "d_41":2, 
                       "d_15": 1, "d_58": 1, "d_66": 1, "d_69": 1, "d_145": 1, "d_173" : 1},
"q_2": { "d_1":2,"d_41":2,"d_65":2,"d_15":1,"d_58":1,"d_66":1,"d_69":1,"d_145":1,"d_173":1},
"q_3": {"d_6":2,"d_17":2,"d_80":2,"d_120":2,"d_122":2,"d_178":2,
      "d_10":1,"d_13":1,"d_14":1,"d_16":1,"d_18":1,"d_19":1,"d_25":1,"d_79":1,"d_86":1,"d_182":1},
"q_4":{"d_32":2,"d_157":2,"d_159":2,"d_162":2,"d_187":2,
      "d_188":1,"d_33":1,"d_34":1,"d_37":1,"d_52":1,"d_62":1,"d_76":1,"d_109":1,"d_163":1,"d_164":1,"d_189":1},
"q_5":{"d_23":2,"d_26":2,"d_71":2,"d_98":2,"d_183":2,"d_186":2,
      "d_22":1,"d_27":1,"d_29":1,"d_49":1,"d_60":1,"d_63":1},
"q_6":{"d_5":2,"d_8":2,"d_9":2,"d_35":2,"d_50":2,"d_52":2,"d_53":2,"d_71":2,"d_90":2,"d_125":2,"d_153":2,"d_192":2,"d_193":2,"d_194":2,
      "d_34":1,"d_45":1,"d_138":1,"d_162":1,"d_168":1},
"q_7":{"d_178":2,"d_4":2,"d_10":2,"d_14":2,"d_80":2,"d_156":2,"d_195":2,
       "d_16":1,"d_19":1,"d_25":1,"d_36":1,"d_48":1,"d_70":1,"d_86":1,"d_91":1,"d_120":1,"d_152":1,"d_167":1,"d_175":1,"d_178":1,"d_179":1
      },
"q_8":{"d_4":2,"d_6":2,"d_13":2,"d_17":2,"d_19":2,"d_178":2,
      "d_18":1,"d_36":1,"d_70":1,"d_79":1},
"q_9":{"d_22":2,"d_27":2,"d_29":2,"d_49":2,"d_60":2,"d_63":2,"d_75":2,"d_84":2,"d_99":2,"d_100":2,"d_101":2,"d_102":2,"d_103":2,"d_104":2,"d_105":2,"d_149":2,"d_150":2,
      "d_23":1,"d_26":1,"d_46":1,"d_61":1,"d_71":1,"d_88":1,"d_89":1,"d_98":1},
"q_10":{"d_91":2,"d_10":2,"d_14":2,"d_195":2,"d_36":2,"d_48":2,"d_140":2,"d_152":2,"d_154":2,"d_156":2,"d_167":2,"d_179":2,"d_195":2,
        "d_16":1,"d_18":1,"d_25":1,"d_42":1,"d_70":1,"d_95":1,"d_175":1},
"q_11":{"d_41":2,"d_65":2,"d_169":2,
      "d_5":1,"d_15":1,"d_24":1,"d_50":1,"d_54":1,"d_58":1,"d_66":1,"d_69":1,"d_145":1,"d_173":1},
"q_12":{"d_70":2,"d_85":2,"d_174":2,"d_177":2,"d_42":2,"d_96":2,
      "d_10":1,"d_16":1,"d_18":1,"d_25":1}      
 }

run_dict = result_dict


qrels = Qrels(qrels_dict)
run = Run(run_dict)

# %%
from ranx import evaluate

# Compute score for a single metric
# evaluate(qrels, run, "ndcg@5")
final_result=evaluate(qrels, run, ["map", "ndcg"])

# Compute scores for multiple metrics at once
# evaluate(qrels, run, ["map@5", "mrr"])
print(final_result)
# Out:
# {'map': 0.10778508771929825, 'ndcg': 0.2394806735442755}

# %%
final_df.to_csv('BM25Result.csv')

# %% [markdown]
# Validation END!!!!!!!!!!!!!!!!!!!!
