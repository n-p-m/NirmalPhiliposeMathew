# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 12.2 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 10.1 MB/s eta 0:00:00
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 83.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.1 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.8 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.1 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.12.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2022.10.31)
# Collecting protobuf<=3.20.2
#   Downloading protobuf-3.20.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.6 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.98-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, sentencepiece, xxhash, protobuf, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 protobuf-3.20.2 responses-0.18.0 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1 xxhash-3.2.0 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
! pip install trafilatura
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting trafilatura
#   Downloading trafilatura-1.5.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.1 MB/s eta 0:00:00
# Collecting charset-normalizer>=3.1.0
#   Downloading charset_normalizer-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2022.12.7)
# Collecting courlan>=0.9.0
#   Downloading courlan-0.9.1-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 5.3 MB/s eta 0:00:00
# Collecting justext>=3.0.0
#   Downloading jusText-3.0.0-py2.py3-none-any.whl (837 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.8/837.8 kB 56.3 MB/s eta 0:00:00
# Collecting htmldate>=1.4.2
#   Downloading htmldate-1.4.2-py3-none-any.whl (33 kB)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (4.9.2)
# Requirement already satisfied: urllib3<2,>=1.26 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (1.26.15)
# Collecting tld>=0.13
#   Downloading tld-0.13-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: langcodes>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from courlan>=0.9.0->trafilatura) (3.3.0)
# Collecting dateparser>=1.1.2
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.4.2->trafilatura) (2.8.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (4.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->htmldate>=1.4.2->trafilatura) (1.16.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->dateparser>=1.1.2->htmldate>=1.4.2->trafilatura) (2023.3)
# Installing collected packages: tld, justext, charset-normalizer, courlan, dateparser, htmldate, trafilatura
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.27.1 requires charset-normalizer~=2.0.0; python_version >= "3", but you have charset-normalizer 3.1.0 which is incompatible.
# Successfully installed charset-normalizer-3.1.0 courlan-0.9.1 dateparser-1.1.8 htmldate-1.4.2 justext-3.0.0 tld-0.13 trafilatura-1.5.0

# %%
from transformers import AutoTokenizer, AutoModel

#model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
model_ckpt = "sentence-transformers/distilbert-base-nli-stsb-mean-tokens"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)
     
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]
  
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="pt"
    )
    #encoded_input = {k: v.to(device) for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/265M [00:00<?, ?B/s]

# %%
import pandas as pd

df=pd.read_csv('Test Links.csv')
df=df['Link']

# %%
df
# Out:
# 0      https://www.psychologytoday.com/us/basics/chil...
# 1      https://www.psychologytoday.com/us/basics/adhd...
# 2      https://www.psychologytoday.com/us/basics/adop...
# 3      https://www.psychologytoday.com/us/basics/auti...
# 4      https://www.psychologytoday.com/us/blog/how-ra...
#                              ...
# 195    https://www.parents.com/parenting/better-paren...
# 196    https://www.parents.com/recipes/scoop-on-food/...
# 197    https://www.parents.com/toddlers-preschoolers/...
# 198    https://www.parents.com/toddlers-preschoolers/...
# 199    https://www.parents.com/toddlers-preschoolers/...
# Name: Link, Length: 200, dtype: object

# %%
from datasets import load_dataset,Dataset

doc_Df = pd.DataFrame(columns=['Title','DocID','URL','Embeddings','Text'])
Dataset_doc_Df=Dataset.from_pandas(doc_Df)

# %%
print(doc_Df)
# Out:
# Empty DataFrame
# Columns: [Title, DocID, URL, Embeddings, Text]
# Index: []

# %% [markdown]
# Adding Title to the complete text

# %%
import pandas as pd

title_dataset=pd.read_csv('ExtractedText.csv')
title_dataset=title_dataset[['DocumentID','Title']]
final_title_dataset = pd.DataFrame(columns=['DocID','Title'])

# drop duplicates and create new dataframe
title_dataset = title_dataset.drop_duplicates(subset=['DocumentID', 'Title'])

print(title_dataset[title_dataset['DocumentID']==4]['Title'].values[0])
# Out:
# Ending Homework Battles | Psychology Today

# %%
import trafilatura

# url='https://www.psychologytoday.com/us/basics/child-development'

for i,url in enumerate(df):
  t=trafilatura.fetch_url(url)
  text=trafilatura.extract(t)
  # doc_Df['DocID'][i]=i
  # doc_Df['URL'][i]=link
  # doc_Df['Embeddings'][i]=get_embeddings(text)
  try:
    title=title_dataset[title_dataset['DocumentID']==i]['Title'].values[0]
    doc_Df.loc[i]=[title,i,url,get_embeddings(text).detach().cpu().numpy()[0],title+text]
  except:
    print("Error in docid-> "+str(i))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3199: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# Error in docid-> 8
# Error in docid-> 20

# %%
doc_Df
# Out:
#                                                  Title  DocID  \
# 0                 Child Development | Psychology Today      0
# 1       Parenting a Child with ADHD | Psychology Today      1
# 2          Raising an Adopted Child | Psychology Today      2
# 3     Parenting a Child with Autism | Psychology Today      3
# 4           Ending Homework Battles | Psychology Today      4
# ..                                                 ...    ...
# 195  My Kid's Toddler Tantrums Are Getting Out of H...    195
# 196  10 Ways to Make Feeding Your Toddler 10 Times ...    196
# 197              Separation and Social Anxiety in Kids    197
# 198                  How Much Does My Kid Need to Eat?    198
# 199      8 Things to Do With Your Placenta After Birth    199
#
#                                                    URL  \
# 0    https://www.psychologytoday.com/us/basics/chil...
# 1    https://www.psychologytoday.com/us/basics/adhd...
# 2    https://www.psychologytoday.com/us/basics/adop...
# 3    https://www.psychologytoday.com/us/basics/auti...
# 4    https://www.psychologytoday.com/us/blog/how-ra...
# ..                                                 ...
# 195  https://www.parents.com/parenting/better-paren...
# 196  https://www.parents.com/recipes/scoop-on-food/...
# 197  https://www.parents.com/toddlers-preschoolers/...
# 198  https://www.parents.com/toddlers-preschoolers/...
# 199  https://www.parents.com/toddlers-preschoolers/...
#
#                                             Embeddings  \
# 0    [0.2803007, 0.23809318, -0.19282328, -0.159848...
# 1    [-0.057591643, 0.2632406, 0.36278155, 0.245281...
# 2    [0.30209792, -0.043051302, -0.1418182, -0.2052...
# 3    [-0.030700075, 0.390369, 0.41788584, -0.278411...
# 4    [0.26746687, 0.18432264, -0.11905984, 0.089509...
# ..                                                 ...
# 195  [0.17019387, -0.038686477, 0.18198003, -0.1769...
# 196  [0.4790843, 0.36725512, -0.06070934, -0.125382...
# 197  [0.097834304, -0.50916183, 0.33884814, -0.6288...
# 198  [0.9504991, 0.4124903, 0.634642, -0.18082817, ...
# 199  [0.5487868, -0.37285843, 0.6230989, -0.5215451...
#
#                                                   Text
# 0    Child Development | Psychology TodayUnderstand...
# 1    Parenting a Child with ADHD | Psychology Today...
# 2    Raising an Adopted Child | Psychology TodayRai...
# 3    Parenting a Child with Autism | Psychology Tod...
# 4    Ending Homework Battles | Psychology TodayEndi...
# ..                                                 ...
# 195  My Kid's Toddler Tantrums Are Getting Out of H...
# 196  10 Ways to Make Feeding Your Toddler 10 Times ...
# 197  Separation and Social Anxiety in KidsRaising K...
# 198  How Much Does My Kid Need to Eat?Family Life F...
# 199  8 Things to Do With Your Placenta After BirthP...
#
# [198 rows x 5 columns]

# %%
doc_Df.to_csv('CompleteMainText.csv')

# %%
embeddings_dataset = Dataset.from_pandas(doc_Df)
embeddings_dataset=embeddings_dataset.remove_columns('__index_level_0__')
embeddings_dataset
# Out:
# Dataset({
#     features: ['Title', 'DocID', 'URL', 'Embeddings', 'Text'],
#     num_rows: 198
# })

# %%
embeddings_dataset.add_faiss_index(column="Embeddings")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['Title', 'DocID', 'URL', 'Embeddings', 'Text'],
#     num_rows: 198
# })

# %%
# loading library
import pickle
# create an iterator object with write permission - model.pkl
with open('Distillbert_DocumentLevel_pkl', 'wb') as files:
    pickle.dump(embeddings_dataset, files)

# We will save/send this file to the Data Base.
